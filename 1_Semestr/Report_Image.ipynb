# %%
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np
from IPython.display import Image, display

# %% [markdown]
# # Отчет и работа модели с изображениями

# %% [markdown]
# ## Обучение Хот-догов

# %% [markdown]
# Заходим на сайт, подписываем названия класса "хот дог" и "не хот-дог", в обоих классах добавляем данные изображения для обучения. Далее обучаем модели ждем завершение его процесса

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\Фото обучение на сайте.png'))

# %% [markdown]
# Проверяем модель с помощью фото из папки hot_dog_validation. Можно увидеть модель считает более вероятно что на фото изображен хот дог

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\Проверка фото  хот-дога.png'))

# %% [markdown]
# На сайте имеется возможность рассмотреть ошибки и точность обучения

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\Статистика хот догов.png'))

# %% [markdown]
# ## Проверка правильности изображений хот-догов

# %% [markdown]
# Изображение - результат обучения хот-догов

# %% [markdown]
# - 133012.jpg - 100/100
# - 133015.jpg - 53/100
# - 133245.jpg - 100/100
# - 135628.jpg - 100/100
# - 138933.jpg - 100/100
# - 138937.jpg - 100/100
# - 138969.jpg - 100/100
# - 139177.jpg - 100/100
# - 142835.jpg - 91/100
# - 143012.jpg - 67/100

# %% [markdown]
# ## Проверка правильности изображений не хот-догов

# %% [markdown]
# Изображение - результат обучения не хот-догов

# %% [markdown]
# - 6229.jpg - 100/100
# - 6261.jpg - 100/100
# - 6709.jpg - 100/100
# - 6926.jpg - 100/100
# - 7056.jpg - 99/100
# - 7394.jpg - 64/100
# - 7847.jpg - 14/100
# - 8119.jpg - 100/100
# - 8350.jpg - 67/100
# - 8917.jpg - 100/100

# %%
# !pip install tensorflow==2.8.0
# !pip install protobuf==3.20.3
# !pip install numpy==1.24.3

# %% [markdown]
# Модель хот дога

# %%
np.set_printoptions(suppress=True)
model = load_model("keras_Model.h5", compile=False)
class_names = open("labels.txt", "r", encoding='utf-8').readlines()
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
image = Image.open("1167.jpg").convert("RGB")
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
image_array = np.asarray(image)
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
data[0] = normalized_image_array
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# Class: не хот-доги
# Confidence Score: 0.9999223

# %% [markdown]
# ## Обучение ноутбуков и телефонов

# %% [markdown]
# Заходим на сайт, подписываем названия класса "Планшет","Телефон" и "Ноутбук", в обоих классах добавляем данные изображения для обучения. Далее обучаем модели ждем завершение его процесса

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\Загрузка данных гаджетов.png'))

# %% [markdown]
# Проверяем модель сделаем фото напрямую. Можно увидеть модель считает более вероятно что на фото изображен телефон на маловероятным планшет

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\Проверка гаджета фото.png'))

# %% [markdown]
# Посмотрим на статистику

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\Статистика гаджетов.png'))

# %% [markdown]
# Модель гаджетов

# %%
np.set_printoptions(suppress=True)
model = load_model("keras_Model.h5", compile=False)

class_names = open("labels.txt", "r", encoding='utf-8').readlines()

data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

image = Image.open("3_big.jpg").convert("RGB")

size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

image_array = np.asarray(image)

normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

data[0] = normalized_image_array

prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# Class: Ноутбук
# Confidence Score: 0.99553657

# %% [markdown]
# ## Мобильное приложение

# %% [markdown]
# Скачиваем приложение на свой телефон приложение. Далее создаем новую задачу назовем его "Гаджеты"

# %% [markdown]
# Добавляем классы

# %%
Тренируем модель

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\до проверки.jpg', width=300))

# %% [markdown]
# Добавляем 10 изображения для обучения модели чтобы его улучшить

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651823_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651822_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651819_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651816_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651818_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651817_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651824_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651825_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651821_y.jpg', width=300))

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651820_y.jpg', width=300))

# %% [markdown]
# Снова тренируем модель для достоверности

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\после проверки.jpg', width=300))

# %% [markdown]
# Сделаем фото напрямую для проверки моделя

# %%
display(Image(filename=r'C:\Users\Пользователь\Desktop\Jypyter_Works\Фото отчет\отчет по мобиле\photo_5323610039706651828_y.jpg', width=300))
